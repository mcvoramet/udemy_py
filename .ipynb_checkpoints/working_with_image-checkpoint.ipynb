# %%
from PIL import Image

# %%
mac = Image.open('macintosh.jpg')

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2560x1600 at 0x7F81DF665BB0>

# %%
mac.size
# Out:
# (2560, 1600)

# %%
mac.filename
# Out:
# 'macintosh.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F81E241F2E0>

# %%
macintosh_think_different = Image.open('macintosh2.jpg')

# %%
macintosh_think_different
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1200 at 0x7F81E291FD00>

# %%
macintosh_think_different.size
# Out:
# (1920, 1200)

# %%
# start at top corner left
x = 0
y = 0

# grab about 10% in y direction, and about 30% in x direction
w = 1920/3
h = 1200/10

macintosh_think_different.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=640x120 at 0x7F81E2A08130>

# %%
mac.size
# Out:
# (2560, 1600)

# %%
halfway = 2560/2

# %%
x = halfway-300
w = halfway+300
y=300
h=1257

# %%
mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=600x957 at 0x7F81DFF06F70>

# %%
computer = mac.crop((x,y,w,h))

# %%
mac.paste(im=computer, box=(0,0))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2560x1600 at 0x7F81DF665BB0>

# %%
mac.paste(im=computer, box=(0,800))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2560x1600 at 0x7F81DF665BB0>

# %%
mac.size
# Out:
# (2560, 1600)

# %%
h,w = mac.size

# %%
new_h = int(h/3)
new_w = int(w/3)

# %%
mac.resize((new_h, new_w))
# Out:
# <PIL.Image.Image image mode=RGB size=853x533 at 0x7F81DFF09220>

# %%
mac.resize((3000,5000))
# Out:
# <PIL.Image.Image image mode=RGB size=3000x5000 at 0x7F81E0866100>

# %%
mac.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=2560x1600 at 0x7F81E27B7C10>

# %%
mac.rotate(90, expand = True)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x2560 at 0x7F81E080B670>

# %%
mac.rotate(120)
# Out:
# <PIL.Image.Image image mode=RGB size=2560x1600 at 0x7F81E27B78E0>

# %%
macintosh_think_different.putalpha(128)

# %%
macintosh_think_different
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=1920x1200 at 0x7F81E291FD00>

# %%
 mac.paste(macintosh_think_different, box=(0,0), mask=macintosh_think_different)

# %%
 mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2560x1600 at 0x7F81DF665BB0>

# %%
mac.save('mac_hypnosis.png')

# %%
mac_hypnosis = Image.open('mac_hypnosis.png')

# %%
mac_hypnosis
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2560x1600 at 0x7F81E029B5E0>
